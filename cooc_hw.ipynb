# %% [markdown]
# <a href="https://colab.research.google.com/github/salomadoma/compling_hse/blob/main/cooc_hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/salomadoma/compling_hse/refs/heads/main/cooccurence_hw/pg1184.txt
# Out:
# --2024-12-26 21:02:49--  https://raw.githubusercontent.com/salomadoma/compling_hse/refs/heads/main/cooccurence_hw/pg1184.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2787202 (2.7M) [text/plain]
# Saving to: ‘pg1184.txt’
#
# pg1184.txt          100%[===================>]   2.66M  --.-KB/s    in 0.08s
#
# 2024-12-26 21:02:49 (34.9 MB/s) - ‘pg1184.txt’ saved [2787202/2787202]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import defaultdict
import re

# %%
file_path = 'pg1184.txt'

# %%
with open(file_path, 'r', encoding='utf-8') as file:
  text = file.read()

# %%
text = text.lower()
text[500:1000]
# Out:
# 'book.\n\ntitle: the count of monte cristo\n\nauthor: alexandre dumas\n        auguste maquet\n\nrelease date: january 1, 1998 [ebook #1184]\n                most recently updated: october 29, 2024\n\nlanguage: english\n\ncredits: anonymous project gutenberg volunteers, dan muller and david widger\n\n\n*** start of the project gutenberg ebook the count of monte cristo ***\nthe count of monte cristo\n\n\n\nby alexandre dumas [père]\n\n\n\n\n\n0009m \n\n\n\n0011m \n\n\n\n0019m \n\n\n\ncontents\n\n\n volume one\nchapter 1. marseilles—the ar'

# %%
text = re.sub(r'[^a-z\s\.\?!]', '', text)
text[50000:100000]
# Out:
# 'was the reply in a low voice. it is edmond and mercds!\n\nah see there now! said caderousse and i did not recognize them!\nhallo dants! hello lovely damsel! come this way and let us know\nwhen the wedding is to be for fernand here is so obstinate he will not\ntell us.\n\nhold your tongue will you? said danglars pretending to restrain\ncaderousse who with the tenacity of drunkards leaned out of the\narbor. try to stand upright and let the lovers make love without\ninterruption. see look at fernand and follow his example he is\nwellbehaved!\n\nm\n\n\n\nfernand probably excited beyond bearing pricked by danglars as the\nbull is by the bandilleros was about to rush out for he had risen\nfrom his seat and seemed to be collecting himself to dash headlong\nupon his rival when mercds smiling and graceful lifted up her\nlovely head and looked at them with her clear and bright eyes. at this\nfernand recollected her threat of dying if edmond died and dropped\nagain heavily on his seat. danglar
# ...

# %%
sentences = re.split(r'[\.\?!]', text)
sentences[1000:1005]
# Out:
# ['\n\nshall we not set forth',
#  ' asked the sweet silvery voice of mercds\ntwo oclock has just struck and you know we are expected in a quarter\nof an hour',
#  '\n\nm\n\n\n\nto be sure',
#  'to be sure',
#  ' cried dants eagerly quitting the table\nlet us go directly']

# %%
sentences = [sentence.split() for sentence in sentences if sentence]
sentences[1010]
# Out:
# ['the', 'company', 'looked', 'at', 'each', 'other', 'in', 'consternation']

# %%
co_occurrence = defaultdict(lambda: defaultdict(int))

# %%
def update_co_occurrence(sentence, window_size=1):
    words = [""] + sentence + [""]
    for i, word in enumerate(words):
        for j in range(max(0, i - window_size), min(len(words), i + window_size + 1)):
            if i != j:
                co_occurrence[word][words[j]] += 1

for sentence in sentences:
    update_co_occurrence(sentence)

# %%
co_occurrence['count']
# Out:
# defaultdict(int,
#             {'the': 1117,
#              'of': 211,
#              'shall': 2,
#              'on': 7,
#              'noirtier': 1,
#              '': 198,
#              'wasthe': 1,
#              'last': 1,
#              'to': 18,
#              'his': 2,
#              'and': 54,
#              'returned': 8,
#              'broke': 1,
#              'for': 13,
#              'are': 5,
#              'was': 27,
#              'this': 6,
#              'replied': 11,
#              'rang': 2,
#              'know': 4,
#              'times': 1,
#              'motioning': 1,
#              'had': 32,
#              'said': 44,
#              'negligently': 1,
#              'you': 38,
#              'frowning': 1,
#              'be': 1,
#              'dear': 47,
#              'it': 5,
#              'carelessly': 2,
#              'in': 31,
#              'really': 4,
#              'coldly': 2,
#              'that': 20,
#              'a': 16,
# ...

# %%
co_occurrence['monte']
# Out:
# defaultdict(int,
#             {'of': 216,
#              'cristo': 1096,
#              'to': 30,
#              'gain': 1,
#              'cristoavail': 1,
#              'not': 2,
#              'at': 16,
#              'pulciano': 1,
#              'approaching': 2,
#              '': 177,
#              'for': 6,
#              'me': 1,
#              'and': 22,
#              'on': 4,
#              'or': 3,
#              'from': 5,
#              'pincio': 3,
#              'the': 3,
#              'citorio': 1,
#              'cristos': 29,
#              'as': 4,
#              'slumber': 1,
#              'said': 280,
#              'in': 4,
#              'returned': 22,
#              'replied': 68,
#              'asked': 23,
#              'is': 3,
#              'talent': 1,
#              'giving': 1,
#              'comedy': 1,
#              'leaving': 2,
#              'with': 1,
#              'which': 11,
#              'm': 3,
#              'continued': 10,
# ...

# %%
tokens = list(co_occurrence.keys())
tokens[:10]
# Out:
# ['',
#  'the',
#  'project',
#  'gutenberg',
#  'ebook',
#  'of',
#  'count',
#  'monte',
#  'cristo',
#  'this']

# %%
co_occurrence_df = pd.DataFrame(co_occurrence).fillna(0).astype(int).reindex(tokens, columns=tokens, fill_value=0)
co_occurrence_df
# Out:
#                    the  project  gutenberg  ebook    of  count  monte  cristo  \
#              104  2042       11         20      2    82    198    177     192
# the         2042     0       39          0      2  3147   1117      3      13
# project       11    39        0         89      0    10      0      0       0
# gutenberg     20     0       89          0      3     0      0      0       0
# ebook          2     2        0          3      0     1      0      0       0
# ...          ...   ...      ...        ...    ...   ...    ...    ...     ...
# originator     0     1        0          0      0     1      0      0       0
# pg             0     0        0          0      0     0      0      0       0
# includes       0     0        0          0      0     0      0      0       0
# subscribe      0     0        0          0      0     0      0      0       0
# newsletter     0     0        0          0      0     0      0      0       0
#
# ...
